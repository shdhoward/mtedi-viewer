# %%
## https://github.com/MTgeophysics/mtpy/blob/develop/examples/workshop/Workshop%20Exercises%20Core.ipynb
## https://mtpy2.readthedocs.io/en/develop/core.html#module-mtpy.core.edi

# %%
# import required modules

import os
from mtpy.core.mt import MT
# Out:
# GDAL_DATA environment variable is not set  Please see https://trac.osgeo.org/gdal/wiki/FAQInstallationAndBuilding#HowtosetGDAL_DATAvariable
# WARNING:mtpy.utils.decorator:GDAL_DATA environment variable is not set  Please see https://trac.osgeo.org/gdal/wiki/FAQInstallationAndBuilding#HowtosetGDAL_DATAvariable
# WARNING:mtpy.utils.decorator:GDAL_DATA environment variable is not set  Please see https://trac.osgeo.org/gdal/wiki/FAQInstallationAndBuilding#HowtosetGDAL_DATAvariable
# Ignore GDAL as it is not working. Will use pyproj
# Ignore GDAL as it is not working. Will use pyproj
# Ignore GDAL as it is not working. Will use pyproj

# %% [markdown]
# #### Using an MT object

# %%
# Read an edi file into an MT object¶
# The mt_obj contains all the data from the edi file, 
# e.g. impedance, tipper, frequency as well as station information (lat/long). 

# Define the path to your edi file
edi_file = "YEN1077A.edi"

# Create an MT object
mt_obj = MT(edi_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-69e6213bdffb> in <module>
#       7
#       8 # Create an MT object
# ----> 9 mt_obj = MT(edi_file)
#
# ~\Anaconda3\lib\site-packages\mtpy\core\mt.py in __init__(self, fn, **kwargs)
#     156         self.original_file_type = None
#     157         if fn is not None:
# --> 158             self.read_mt_file(fn)
#     159             self._fn = os.path.normpath(os.path.abspath(fn))  # store file reference
#     160
#
# ~\Anaconda3\lib\site-packages\mtpy\core\mt.py in read_mt_file(self, fn, file_type)
#     364
#     365         if file_type.lower() == 'edi':
# --> 366             self._read_edi_file(fn)
#     367         elif file_type.lower() == 'j':
#     368             self._read_j_file(fn)
#
# ~\Anaconda3\lib\site-packages\mtpy\core\mt.py in _read_edi_file(self, edi_fn)
# ...

# %% [markdown]
# mt_obj.Copyright            mt_obj.Z                    mt_obj.north                mt_obj.remove_static_shift(
# mt_obj.FieldNotes           mt_obj.east                 mt_obj.original_file_type   mt_obj.rotation_angle
# mt_obj.Notes                mt_obj.elev                 mt_obj.plot_mt_response(    mt_obj.save_dir
# mt_obj.Processing           mt_obj.fn                   mt_obj.pt                   mt_obj.station
# mt_obj.Provenance           mt_obj.interpolate(         mt_obj.read_cfg_file(       mt_obj.utm_zone
# mt_obj.Site                 mt_obj.lat                  mt_obj.read_mt_file(        mt_obj.write_cfg_file(
# mt_obj.Tipper               mt_obj.lon                  mt_obj.remove_distortion(   mt_obj.write_mt_file(

# %%
# To look at any of these parameters:
print (mt_obj.station, mt_obj.lat, mt_obj.lon, mt_obj.elev )
# Out:
# LAV01A -28.84263888888889 124.50780555555555 338.0

# %%
print(mt_obj.Provenance.creation_time)
# Out:
# 2020-04-02 21:36:19

# %%
print(mt_obj.Site.id, mt_obj.Site.start_date, mt_obj.Site.end_date)
# Out:
# LAV01A 10/01/12 10/01/1213

# %%
print(mt_obj.Site.Location)

# %%
#  frequency values represented in the impedance tensor:
print (mt_obj.Z.freq)
# Out:
# [3.200001e+02 2.650000e+02 2.290000e+02 1.940000e+02 1.590000e+02
#  1.320000e+02 1.150000e+02 9.699999e+01 7.900001e+01 6.600000e+01
#  5.700000e+01 4.900000e+01 4.000000e+01 3.300000e+01 2.750000e+01
#  2.250000e+01 1.880000e+01 1.620000e+01 1.370000e+01 1.120000e+01
#  9.400000e+00 8.100000e+00 6.900000e+00 5.600000e+00 4.700000e+00
#  4.100000e+00 3.400000e+00 2.810000e+00 2.340000e+00 2.030000e+00
#  1.720000e+00 1.410000e+00 1.170000e+00 1.020000e+00 8.600000e-01
#  7.000000e-01 5.900000e-01 5.100000e-01 4.300000e-01 3.500000e-01
#  2.930000e-01 2.540000e-01 2.150000e-01 1.760000e-01 1.460000e-01
#  1.270000e-01 1.070000e-01 8.800000e-02 7.300000e-02 6.300001e-02
#  5.400000e-02 4.400000e-02 3.700000e-02 3.200000e-02 2.690000e-02
#  2.200000e-02 1.830000e-02 1.590000e-02 1.340000e-02 1.100000e-02
#  9.199999e-03 7.900001e-03 6.700001e-03 5.500000e-03 4.600001e-03
#  4.000001e-03 3.400000e-03 2.750000e-03 2.290000e-03 1.980000e-03
# ...

# %%
# the impedance tensor (first 4 elements)
print (mt_obj.Z.z[:4])
# Out:
# [[[  1.032746  +2.832259j   21.62675  +38.12355j  ]
#   [-18.10679  -31.21486j    -1.912309  -1.451626j ]]
#
#  [[  0.3084295 +2.257987j   19.13527  +34.61301j  ]
#   [-16.93445  -29.33341j    -1.505684  -0.9934247j]]
#
#  [[  1.197007  +1.489139j   17.85324  +31.73587j  ]
#   [-17.159    -27.15904j    -1.107539  -0.5075806j]]
#
#  [[  0.7133126 +1.541481j   16.24153  +28.68697j  ]
#   [-15.21172  -25.00196j    -0.995975  -0.7407705j]]]

# %% [markdown]
# #### Using mtpy.core.edi

# %%
import mtpy.core.edi as MTedi

# %%
# from pylab import *

# %%
edi = MTedi.Edi(edi_fn=r'YEN1077A.edi')

id =  edi.Header.dataid
lon = edi.Header.lon
lat = edi.Header.lat
elev = edi.Header.elev
print (id, lat, lon, elev)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a29478f69eb9> in <module>
# ----> 1 edi = MTedi.Edi(edi_fn=r'YEN1077A.edi')
#       2
#       3 id =  edi.Header.dataid
#       4 lon = edi.Header.lon
#       5 lat = edi.Header.lat
#
# ~\Anaconda3\lib\site-packages\mtpy\core\edi.py in __init__(self, edi_fn)
#     137
#     138         if self.edi_fn is not None:
# --> 139             self.read_edi_file()
#     140
#     141     def read_edi_file(self, edi_fn=None):
#
# ~\Anaconda3\lib\site-packages\mtpy\core\edi.py in read_edi_file(self, edi_fn)
#     188         self.Data_sect = DataSection(edi_lines=self._edi_lines)
#     189
# --> 190         self._read_data()
#     191
#     192         if self.Header.lat is None:
#
# ~\Anaconda3\lib\site-packages\mtpy\core\edi.py in _read_data(self)
#     237
#     238         elif self.Data_sect.data_type == 'z':
# ...

# %%
pt_obj = mt_obj.plot_mt_response(plot_num=1, # 1 = yx and xy; 2 = all 4 components
                                            # 3 = off diagonal + determinant
                                 plot_tipper = 'yri',
                                 plot_pt = 'y' # plot phase tensor 'y' or 'n'
                                )
